# %%
# !pip install pytrends
# Out:
# Collecting pytrends
#   Downloading pytrends-4.9.2-py3-none-any.whl (15 kB)
# Requirement already satisfied: requests>=2.0 in c:\users\t14\appdata\local\programs\python\python311\lib\site-packages (from pytrends) (2.31.0)
# Requirement already satisfied: pandas>=0.25 in c:\users\t14\appdata\local\programs\python\python311\lib\site-packages (from pytrends) (2.1.1)
# Collecting lxml (from pytrends)
#   Downloading lxml-4.9.3-cp311-cp311-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\t14\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.25->pytrends) (1.26.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\t14\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.25->pytrends) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\t14\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.25->pytrends) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\t14\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.25->pytrends) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\t14\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.0->pytrends) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\t14\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.0->pytrends) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\t14\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.0->pytrends) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\t14\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.0->pytrends) (2023.7.22)
# Requirement already satisfied: six>=1.5 in c:\users\t14\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.25->pytrends) (1.16.0)
# Downloading lxml-4.9.3-cp311-cp311-win_amd64.whl (3.8 MB)
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#     --------------------------------------- 0.1/3.8 MB 1.6 MB/s eta 0:00:03
#    -- ------------------------------------- 0.2/3.8 MB 2.5 MB/s eta 0:00:02
#    ----- ---------------------------------- 0.5/3.8 MB 4.2 MB/s eta 0:00:01
#    ----------- ---------------------------- 1.1/3.8 MB 6.2 MB/s eta 0:00:01
#    ------------------- -------------------- 1.8/3.8 MB 8.3 MB/s eta 0:00:01
#    ------------------------ --------------- 2.3/3.8 MB 9.7 MB/s eta 0:00:01
#    ---------------------------------------  3.7/3.8 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 11.5 MB/s eta 0:00:00
# Installing collected packages: lxml, pytrends
# Successfully installed lxml-4.9.3 pytrends-4.9.2

# %%
from pytrends.request import TrendReq

pytrends = TrendReq(hl='en-US', tz=360)

# %%
# build payload

kw_list = ["machine learning"] # list of keywords to get data 

pytrends.build_payload(kw_list, cat=0, timeframe='today 12-m')

# %%
#1 Interest over Time
data = pytrends.interest_over_time() 
data = data.reset_index() 


# import plotly.express as px

# fig = px.line(data, x="date", y=['machine learning'], title='Keyword Web Search Interest Over Time')
# fig.show()

# %%
data.head()
# Out:
#         date  machine learning  isPartial
# 0 2022-12-11                91      False
# 1 2022-12-18                78      False
# 2 2022-12-25                68      False
# 3 2023-01-01                79      False
# 4 2023-01-08                91      False

# %%
data  = pytrends.related_queries()

data['machine learning']['top']
# Out:
#                                            query  value
# 0                       what is machine learning    100
# 1                            ai machine learning     87
# 2                                             ai     81
# 3                        python machine learning     79
# 4                                         python     76
# 5                         machine learning model     60
# 6                                  deep learning     51
# 7                        google machine learning     46
# 8                                     regression     42
# 9                        artificial intelligence     36
# 10                                  data science     33
# 11                       ai and machine learning     32
# 12                   machine learning algorithms     32
# 13                       machine learning models     31
# 14                                            ml     31
# 15                     machine learning engineer     30
# 16                       machine learning course     30
# 17                      machine learning meaning     26
# 18                regression in machine learning     24
# 19  artificial intelligence and machine learning     23
# 20                                        github     22
# 21                   supervised machine learning     20
# 22                           supervised learning     20
# 23                         machine learning jobs     18
# 24                     machine learning training     18
